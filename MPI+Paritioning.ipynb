# %%
a=range(2,1023)
# Out:
# 2:1024

# %%
using conda
# Out:
# ArgumentError: Module conda not found in current path.
# Run `Pkg.add("conda")` to install the conda package.
#
# Stacktrace:
#  [1] _require(::Symbol) at ./loading.jl:428
#  [2] require(::Symbol) at ./loading.jl:398
#  [3] include_string(::String, ::String) at ./loading.jl:515

# %%
b=8192%a
# Out:
# WARNING: rem(A::Number, B::AbstractArray) is deprecated, use rem.(A, B) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] rem(::Int64, ::UnitRange{Int64}) at ./deprecated.jl:57
#  [3] include_string(::String, ::String) at ./loading.jl:515
#  [4] include_string(::Module, ::String, ::String) at /Users/maclach/.julia/v0.6/Compat/src/Compat.jl:478
#  [5] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/maclach/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [6] eventloop(::ZMQ.Socket) at /Users/maclach/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [7] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[26], in expression starting on line 1
# 1023-element Array{Int64,1}:
#   0
#   2
#   0
#   2
#   2
#   2
#   0
#   2
#   2
#   8
#   8
#   2
#   2
#   ⋮
#  88
#  80
#  72
#  64
#  56
#  48
#  40
#  32
#  24
#  16
#   8
#   0

# %%
using PyPlot

# %%
plot(a[600:800],b[600:800] )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1334d72d0>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x13361f790>

# %%
plot(a[800:1000],b[800:1000] )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1337760d0>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x132dc8090>

# %%
plot(a[1:400],b[1:400] )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1337c3a50>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x133b78350>

# %%
plot(a[1:200],b[1:200] )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x133b5d290>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x133cdf810>

# %%
plot(a[115:150],b[115:150] )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x133a2b350>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x133ec4210>

# %%
plot(a[75:100],b[75:100] )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x133edad10>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x13402c1d0>

# %%
plot(a[1:100],b[1:100] )
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x134039350>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x13409d810>
